# %%
import os, shutil, random, pathlib
from collections import defaultdict

random.seed(1337)  # Fijamos la semilla para que las selecciones sean reproducibles.

src_dir = "PruebaDataset"            # Indicamos la carpeta de origen con subcarpetas por clase.
dst_dir = "PruebaDataset_balanced"   # Indicamos la carpeta de destino donde crearemos el dataset balanceado.
extensions = {".jpg", ".jpeg", ".png", ".bmp", ".gif"}  # Definimos las extensiones de imagen permitidas.

# 1) Recolectamos rutas por clase.
files_by_class = defaultdict(list)
for cls in sorted(os.listdir(src_dir)):
    cpath = os.path.join(src_dir, cls)
    if not os.path.isdir(cpath):
        continue  # Ignoramos entradas que no sean directorios de clase.
    for root, _, files in os.walk(cpath):
        for f in files:
            if pathlib.Path(f).suffix.lower() in extensions:
                files_by_class[cls].append(os.path.join(root, f))  # Añadimos la ruta de cada imagen válida.

# 2) Calculamos cuántas imágenes hay por clase y definimos N objetivo por clase.
counts = {cls: len(v) for cls, v in files_by_class.items()}
min_count = min(counts.values())  # Obtenemos el mínimo por si queremos usarlo como límite inferior.
N = 100  # Definimos el número de muestras por clase, ajustable según disponibilidad por clase.

print("Imágenes por clase:", counts)  # Mostramos el conteo de imágenes por clase para diagnóstico.
print(f"Usando N={N} por clase")  # Confirmamos el N elegido por clase.

# 3) Creamos la carpeta de destino limpia.
if os.path.exists(dst_dir):
    shutil.rmtree(dst_dir)  # Eliminamos el destino si existía para evitar mezclas previas.
os.makedirs(dst_dir, exist_ok=True)  # Creamos la carpeta de destino desde cero.

# 4) Definimos helper para enlazar o copiar archivos según el sistema.
def link_or_copy(src, dst):
    try:
        os.symlink(os.path.abspath(src), dst)  # Creamos un enlace simbólico para ahorrar espacio cuando sea posible.
    except Exception:
        shutil.copy2(src, dst)  # Copiamos físicamente el archivo si no podemos crear el enlace.

# 5) Seleccionamos N imágenes aleatorias por clase y las escribimos en el destino.
for cls, paths in files_by_class.items():
    random.shuffle(paths)  # Barajamos las rutas para muestrear aleatoriamente.
    keep = paths[:N]  # Tomamos las primeras N rutas tras el barajado.
    out_cls = os.path.join(dst_dir, cls)
    os.makedirs(out_cls, exist_ok=True)  # Creamos la subcarpeta de la clase en el destino.
    for i, p in enumerate(keep):
        ext = pathlib.Path(p).suffix.lower()
        dst_path = os.path.join(out_cls, f"{cls}_{i:05d}{ext}")  # Generamos un nombre de archivo estable y ordenable.
        link_or_copy(p, dst_path)  # Enlazamos o copiamos la imagen al destino.

print("✓ Dataset balanceado creado en:", dst_dir)  # Indicamos finalización y la ruta del dataset balanceado.

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import json

# -----------------------------------------------------------------------------
# 1) Configuración reproducible.
# -----------------------------------------------------------------------------
SEED = 1337
tf.random.set_seed(SEED)
np.random.seed(SEED)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # Silenciamos los logs de TensorFlow para mantener la salida limpia.

# -----------------------------------------------------------------------------
# 2) Generadores de datos (consistentes con ResNet50V2).
# -----------------------------------------------------------------------------
from tensorflow.keras.applications.resnet_v2 import preprocess_input as resnet_preprocess

img_size = (256, 256)
batch_size = 32
target_shape = (*img_size, 3)

# Creamos el generador de datos con aumentación para el entrenamiento.
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    preprocessing_function=resnet_preprocess
)

# Creamos el generador de datos para validación solo con preprocesamiento.
valid_datagen = ImageDataGenerator(
    preprocessing_function=resnet_preprocess
)

# Cargamos las imágenes de entrenamiento desde la carpeta correspondiente.
data_gen_entrenamiento = train_datagen.flow_from_directory(
    "PruebaDataset",
    target_size=img_size,
    batch_size=batch_size,
    shuffle=True,
    seed=SEED,
    class_mode="categorical",
    color_mode="rgb"
)

# Obtenemos los nombres de las clases y la cantidad total detectada.
class_names = list(data_gen_entrenamiento.class_indices.keys())
num_classes = len(class_names)
print("Clases detectadas en TRAIN:", num_classes)
print(class_names)

#with open("class_names.json", "w", encoding="utf-8") as f:
#    json.dump(class_names, f, ensure_ascii=False, indent=2)


# Creamos el generador de validación, forzando el mismo orden de clases.
data_gen_pruebas = valid_datagen.flow_from_directory(
    "PruebaDataset",
    target_size=img_size,
    batch_size=batch_size,
    shuffle=True,
    seed=SEED,
    class_mode="categorical",
    color_mode="rgb",
    classes=class_names
)

# -----------------------------------------------------------------------------
# 3) Definición del modelo (ResNet50V2 base + capa de clasificación).
# -----------------------------------------------------------------------------
def crear_modelo_resnet(input_shape, n_classes):
    from tensorflow.keras.applications import ResNet50V2

    # Cargamos la base preentrenada sin la parte superior.
    base = ResNet50V2(
        include_top=False,
        weights="imagenet",
        input_shape=input_shape,
        pooling="avg",
        name="resnet50v2"
    )
    base.trainable = False  # Mantenemos la base congelada inicialmente.

    # Definimos la arquitectura del modelo completo.
    inputs = keras.Input(shape=input_shape)
    x = base(inputs, training=False)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)

    # Compilamos el modelo con Adam y entropía cruzada categórica.
    model = keras.Model(inputs, outputs)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# -----------------------------------------------------------------------------
# 4) Creación del modelo.
# -----------------------------------------------------------------------------
model = crear_modelo_resnet(target_shape, num_classes)
model.summary()

# -----------------------------------------------------------------------------
# 5) Definición de callbacks.
# -----------------------------------------------------------------------------
callbacks_iniciales = [
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=8,
        restore_best_weights=True,
        min_delta=0.001
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=3,
        verbose=1,
        min_lr=1e-7
    )
]

# -----------------------------------------------------------------------------
# 6) Entrenamiento inicial con la base congelada.
# -----------------------------------------------------------------------------
print("🚀 Entrenamiento inicial...")
historial = model.fit(
    data_gen_entrenamiento,
    epochs=30,
    validation_data=data_gen_pruebas,
    callbacks=callbacks_iniciales,
    verbose=1
)

# -----------------------------------------------------------------------------
# 7) Fine-tuning: descongelamos las capas superiores de la base.
# -----------------------------------------------------------------------------
print("🔧 Fine-tuning...")

base_model = model.get_layer("resnet50v2")
N = 30  # Número de capas superiores a descongelar.
for layer in base_model.layers[-N:]:
    if not isinstance(layer, layers.BatchNormalization):
        layer.trainable = True

# Recompilamos con una tasa de aprendizaje más baja.
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

callbacks_ft = [
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=4,
        restore_best_weights=True
    )
]

historial_ft = model.fit(
    data_gen_entrenamiento,
    epochs=10,
    validation_data=data_gen_pruebas,
    callbacks=callbacks_ft,
    verbose=1
)

# -----------------------------------------------------------------------------
# 8) Evaluación final del modelo.
# -----------------------------------------------------------------------------
print("📊 Evaluación final en validación:")
val_loss, val_acc = model.evaluate(data_gen_pruebas, verbose=0)
print(f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")

#model.save("modelo.h5")

# -----------------------------------------------------------------------------
# 9) Visualización de las curvas de entrenamiento.
# -----------------------------------------------------------------------------
acc = historial.history.get('accuracy', []) + historial_ft.history.get('accuracy', [])
val_acc = historial.history.get('val_accuracy', []) + historial_ft.history.get('val_accuracy', [])
loss = historial.history.get('loss', []) + historial_ft.history.get('loss', [])
val_loss_hist = historial.history.get('val_loss', []) + historial_ft.history.get('val_loss', [])

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(acc)
plt.plot(val_acc)
plt.title('Precisión del modelo.')
plt.ylabel('Precisión.')
plt.xlabel('Época.')
plt.legend(['Entrenamiento', 'Validación'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(loss)
plt.plot(val_loss_hist)
plt.title('Pérdida del modelo.')
plt.ylabel('Pérdida.')
plt.xlabel('Época.')
plt.legend(['Entrenamiento', 'Validación'], loc='upper left')

plt.tight_layout()
plt.show()

# -----------------------------------------------------------------------------
# 10) Cálculo de métricas por clase y matriz de confusión.
# -----------------------------------------------------------------------------
from sklearn.metrics import classification_report, confusion_matrix

# Obtenemos las predicciones sobre el conjunto de validación.
y_true = data_gen_pruebas.classes
y_prob = model.predict(data_gen_pruebas, verbose=1)
y_pred = np.argmax(y_prob, axis=1)

# Generamos el informe de clasificación por clase.
labels_all = np.arange(num_classes)

print("\n📄 Classification report por clase:")
print(classification_report(
    y_true,
    y_pred,
    labels=labels_all,
    target_names=class_names,
    digits=4,
    zero_division=0
))

# Calculamos la matriz de confusión.
cm = confusion_matrix(y_true, y_pred, labels=labels_all)
print("\n🔢 Matriz de confusión (filas=verdadero, columnas=predicho):")
print(cm)

# Calculamos la exactitud por clase.
cm_diag = np.diag(cm)
support = cm.sum(axis=1)
acc_per_class = cm_diag / np.maximum(support, 1)

print("\n✅ Exactitud por clase:")
for name, acc_c, sup in zip(class_names, acc_per_class, support):
    print(f" - {name:<20s} acc={acc_c:7.4f}  soporte={sup}")
# Out:
# Found 11850 images belonging to 120 classes.
# Clases detectadas en TRAIN: 120
# ['Aguacate', 'Anacardos', 'Banana', 'Berberechos', 'Calabacín', 'Calabaza', 'Canela', 'Canónigos', 'Carne Cerdo', 'Carne Conejo', 'Carne Cordero', 'Carne Pavo', 'Carne Ternera', 'Carne picada', 'Chorizo', 'Cilantro', 'Clavo', 'Coliflor', 'Curry', 'Cuscus', 'Espaguetis', 'Espinacas', 'Fideos', 'Gambas', 'Garbanzos', 'Grosellas', 'Guisantes', 'Hierbabuena', 'Jamon iberico', 'Levadura', 'Lima', 'Limón', 'Mantequilla', 'Mayonesa', 'Mejillones', 'Melocotones', 'Melón', 'Membrillo', 'Merluza', 'Miel', 'Mora', 'Morcilla', 'Mostaza', 'Naranja', 'Nata líquida', 'Nueces', 'Nuez moscada', 'Níscalos', 'Orégano', 'Pechuga de pollo', 'Salmon', 'Tomillo', 'Zanahoria', 'aceitunas', 'acelgas', 'ajo', 'albahaca', 'alcachofa', 'almejas', 'almendras', 'apio', 'arroz', 'atun fresco', 'avellanas', 'azucar', 'bacalao', 'berenjena', 'boniato', 'boquerones', 'brocoli', 'calamares', 'cebollas', 'cerezas', 'champinones', 'chirimoya', 'chocolate', 'col', 'huevos', 'judías verdes', 'langostinos', 'laurel', 'leche', 'lechuga', 'lentejas', 'manzana', 'pan rallado', 'pasta macarrones', 'patata', 'pepino', 'pera', 'perejil', 'pimentón', 'pimienta blanca', 'pimienta negra', 'pimiento amarillo', 'pimiento rojo', 'pimiento verde', 'pistacho', 'piñones', 'platano', 'puerro', 'pulpo', 'queso fresco', 'queso manchego', 'quinoa', 'rabanitos', 'romero', 'rucula', 'sal', 'sandia', 'sardinas', 'sepia', 'setas variadas', 'tomate', 'tomate cherry', 'uva', 'vinagre balsamico', 'vino blanco', 'vino tinto', 'yogur natural']
# Found 11850 images belonging to 120 classes.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 256, 256, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50v2 (Functional)              │ (None, 2048)                │      23,564,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 120)                 │         245,880 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,810,680 (90.83 MB)
#  Trainable params: 245,880 (960.47 KB)
#  Non-trainable params: 23,564,800 (89.89 MB)
# 🚀 Entrenamiento inicial...
# C:\Users\Jose\anaconda3\envs\Proyecto\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# C:\Users\Jose\anaconda3\envs\Proyecto\Lib\site-packages\PIL\Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1462s 4s/step - accuracy: 0.4327 - loss: 2.3527 - val_accuracy: 0.7327 - val_loss: 0.9950 - learning_rate: 0.0010
# Epoch 2/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1321s 4s/step - accuracy: 0.6727 - loss: 1.1789 - val_accuracy: 0.8208 - val_loss: 0.6721 - learning_rate: 0.0010
# Epoch 3/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1403s 4s/step - accuracy: 0.7358 - loss: 0.9262 - val_accuracy: 0.8576 - val_loss: 0.5294 - learning_rate: 0.0010
# Epoch 4/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1484s 4s/step - accuracy: 0.7702 - loss: 0.7851 - val_accuracy: 0.8771 - val_loss: 0.4467 - learning_rate: 0.0010
# Epoch 5/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1508s 4s/step - accuracy: 0.8030 - loss: 0.6699 - val_accuracy: 0.8964 - val_loss: 0.3735 - learning_rate: 0.0010
# Epoch 6/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1589s 4s/step - accuracy: 0.8173 - loss: 0.6091 - val_accuracy: 0.9165 - val_loss: 0.3115 - learning_rate: 0.0010
# Epoch 7/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1596s 4s/step - accuracy: 0.8317 - loss: 0.5577 - val_accuracy: 0.9216 - val_loss: 0.2897 - learning_rate: 0.0010
# Epoch 8/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1311s 4s/step - accuracy: 0.8422 - loss: 0.5172 - val_accuracy: 0.9336 - val_loss: 0.2510 - learning_rate: 0.0010
# Epoch 9/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1373s 4s/step - accuracy: 0.8513 - loss: 0.4812 - val_accuracy: 0.9376 - val_loss: 0.2312 - learning_rate: 0.0010
# Epoch 10/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1126s 3s/step - accuracy: 0.8595 - loss: 0.4521 - val_accuracy: 0.9387 - val_loss: 0.2178 - learning_rate: 0.0010
# Epoch 11/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1118s 3s/step - accuracy: 0.8678 - loss: 0.4249 - val_accuracy: 0.9398 - val_loss: 0.2064 - learning_rate: 0.0010
# Epoch 12/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1118s 3s/step - accuracy: 0.8754 - loss: 0.3970 - val_accuracy: 0.9473 - val_loss: 0.1803 - learning_rate: 0.0010
# Epoch 13/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1120s 3s/step - accuracy: 0.8774 - loss: 0.3847 - val_accuracy: 0.9512 - val_loss: 0.1718 - learning_rate: 0.0010
# Epoch 14/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1119s 3s/step - accuracy: 0.8851 - loss: 0.3604 - val_accuracy: 0.9568 - val_loss: 0.1531 - learning_rate: 0.0010
# Epoch 15/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1119s 3s/step - accuracy: 0.8851 - loss: 0.3543 - val_accuracy: 0.9554 - val_loss: 0.1510 - learning_rate: 0.0010
# Epoch 16/30
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 
10
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1296s 3s/step - accuracy: 0.9681 - loss: 0.0950 - val_accuracy: 0.9946 - val_loss: 0.0223
# Epoch 10/10
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 1550s 4s/step - accuracy: 0.9705 - loss: 0.0883 - val_accuracy: 0.9945 - val_loss: 0.0208
# 📊 Evaluación final en validación:
# Val Loss: 0.0235 | Val Acc: 0.9946
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 689s 2s/step
#
# 📄 Classification report por clase:
#                    precision    recall  f1-score   support
#
#          Aguacate     1.0000    1.0000    1.0000       100
#         Anacardos     0.9899    1.0000    0.9949        98
#            Banana     0.9901    1.0000    0.9950       100
#       Berberechos     0.9900    0.9900    0.9900       100
#         Calabacín     1.0000    1.0000    1.0000       100
#          Calabaza     1.0000    1.0000    1.0000       100
#            Canela     1.0000    0.9800    0.9899       100
#         Canónigos     1.0000    1.0000    1.0000        98
#       Carne Cerdo     0.9900    0.9900    0.9900       100
#      Carne Conejo     0.9800    0.9800    0.9800       100
#     Carne Cordero     0.9897    0.9600    0.9746       100
#        Carne Pavo     0.9798    0.9700    0.9749       100
#     Carne Ternera     1.0000    1.0000    1.0000       100
#      Carne picada     0.9901    1.0000    0.9950       100
#           Chorizo     0.9901    1.0000    0.9950       100
#          Cilantro     0.9896    0.9896    0.9896        96
#             Clavo     1.0000    1.0000    1.0000       100
#          Coliflor     1.0000    0.9900    0.9950       100
#             Curry     0.9800    0.9800    0.9800       100
#            Cuscus     0.9900    0.9900    0.9900       100
#        Espaguetis     1.0000    1.0000    1.0000       100
#         Espinacas     1.0000    1.0000    1.0000        99
#            Fideos     1.0000    0.9800    0.9899       100
#            Gambas     1.0000    0.9900    0.9950       100
#         Garbanzos     1.0000    0.9900    0.9950       100
#         Grosellas     1.0000    0.9800    0.9899       100
#         Guisantes     1.0000    1.0000    1.0000       100
#       Hierbabuena     1.0000    1.0000    1.0000       100
#     Jamon iberico     1.0000    1.0000    1.0000       100
#          Levadura     0.9901    1.0000    0.9950       100
#              Lima     1.0000    1.0000    1.0000       100
#             Limón     1.0000    0.9894    0.9947        94
#       Mantequilla     1.0000    1.0000    1.0000        99
#          Mayonesa     1.0000    1.0000    1.0000       100
#        Mejillones     1.0000    1.0000    1.0000       100
#       Melocotones     1.0000    1.0000    1.0000       103
#             Melón     1.0000    0.9900    0.9950       100
#         Membrillo     1.0000    1.0000    1.0000       100
#           Merluza     1.0000    0.9900    0.9950       100
#              Miel     1.0000    1.0000    1.0000       100
#              Mora     0.9901    1.0000    0.9950       100
#          Morcilla     1.0000    0.9900    0.9950       100
#           Mostaza     1.0000    1.0000    1.0000       100
#           Naranja     0.9901    1.0000    0.9950       100
#      Nata líquida     0.9899    0.9800    0.9849       100
#            Nueces     0.9901    1.0000    0.9950       100
#      Nuez moscada     0.9796    0.9600    0.9697       100
#          Níscalos     0.9901    1.0000    0.9950       100
#           Orégano     0.9700    1.0000    0.9848        97
#  Pechuga de pollo     0.9880    1.0000    0.9939        82
#            Salmon     0.9881    1.0000    0.9940        83
#           Tomillo     1.0000    0.9897    0.9948        97
#         Zanahoria     1.0000    1.0000    1.0000       100
#        vino tinto     0.9804    1.0000    0.9901       100
#     yogur natural     1.0000    1.0000    1.0000        98
#
#          accuracy                         0.9946     11850
#         macro avg     0.9947    0.9946    0.9946     11850
#      weighted avg     0.9947    0.9946    0.9946     11850
#
#
# 🔢 Matriz de confusión (filas=verdadero, columnas=predicho):
# [[100   0   0 ...   0   0   0]
#  [  0  98   0 ...   0   0   0]
#  [  0   0 100 ...   0   0   0]
#  ...
#  [  0   0   0 ...  96   1   0]
#  [  0   0   0 ...   0 100   0]
#  [  0   0   0 ...   0   0  98]]
#
# ✅ Exactitud por clase:
#  - Aguacate             acc= 1.0000  soporte=100
#  - Anacardos            acc= 1.0000  soporte=98
#  - Banana               acc= 1.0000  soporte=100
#  - Berberechos          acc= 0.9900  soporte=100
#  - Calabacín            acc= 1.0000  soporte=100
#  - Calabaza             acc= 1.0000  soporte=100
#  - Canela               acc= 0.9800  soporte=100
#  - Canónigos            acc= 1.0000  soporte=98
#  - Carne Cerdo          acc= 0.9900  soporte=100
#  - Carne Conejo         acc= 0.9800  soporte=100
#  - Carne Cordero        acc= 0.9600  soporte=100
#  - Carne Pavo           acc= 0.9700  soporte=100
#  - Carne Ternera        acc= 1.0000  soporte=100
#  - Carne picada         acc= 1.0000  soporte=100
#  - Chorizo              acc= 1.0000  soporte=100
#  - Cilantro             acc= 0.9896  soporte=96
#  - Clavo                acc= 1.0000  soporte=100
#  - Coliflor             acc= 0.9900  soporte=100
#  - Curry                acc= 0.9800  soporte=100
#  - Cuscus               acc= 0.9900  soporte=100
#  - Espaguetis           acc= 1.0000  soporte=100
#  - Espinacas            acc= 1.0000  soporte=99
#  - Fideos               acc= 0.9800  soporte=100
#  - Gambas               acc= 0.9900  soporte=100
#  - Garbanzos            acc= 0.9900  soporte=100
#  - Grosellas            acc= 0.9800  soporte=100
#  - Guisantes            acc= 1.0000  soporte=100
#  - Hierbabuena          acc= 1.0000  soporte=100
#  - Jamon iberico        acc= 1.0000  soporte=100
#  - Levadura             acc= 1.0000  soporte=100
#  - Lima                 acc= 1.0000  soporte=100
#  - Limón                acc= 0.9894  soporte=94
#  - Mantequilla          acc= 1.0000  soporte=99
#  - Mayonesa             acc= 1.0000  soporte=100
#  - Mejillones           acc= 1.0000  soporte=100
#  - Melocotones          acc= 1.0000  soporte=103
#  - Melón                acc= 0.9900  soporte=100
#  - Membrillo            acc= 1.0000  soporte=100
#  - Merluza              acc= 0.9900  soporte=100
#  - Miel                 acc= 1.0000  soporte=100
#  - Mora                 acc= 1.0000  soporte=100
#  - Morcilla             acc= 0.9900  soporte=100
#  - Mostaza              acc= 1.0000  soporte=100
#  - Naranja              acc= 1.0000  soporte=100
#  - Nata líquida         acc= 0.9800  soporte=100
#  - Nueces               acc= 1.0000  soporte=100
#  - Nuez moscada         acc= 0.9600  soporte=100
#  - Níscalos             acc= 1.0000  soporte=100
#  - Orégano              acc= 1.0000  soporte=97
#  - Pechuga de pollo     acc= 1.0000  soporte=82
#  - Salmon               acc= 1.0000  soporte=83
#  - Tomillo              acc= 0.9897  soporte=97
#  - Zanahoria            acc= 1.0000  soporte=100
#  - aceitunas            acc= 1.0000  soporte=100
#  - acelgas              acc= 0.9900  soporte=100
#  - ajo                  acc= 1.0000  soporte=100
#  - albahaca             acc= 1.0000  soporte=100
#  - alcachofa            acc= 1.0000  soporte=100
#  - almejas              acc= 0.9900  soporte=100
#  - almendras            acc= 1.0000  soporte=99
#  - apio                 acc= 1.0000  soporte=100
#  - arroz                acc= 1.0000  soporte=100
#  - atun fresco          acc= 0.9787  soporte=94
#  - avellanas            acc= 0.9900  soporte=100
#  - azucar               acc= 0.9900  soporte=100
#  - bacalao              acc= 1.0000  soporte=100
#  - berenjena            acc= 1.0000  soporte=95
#  - boniato              acc= 1.0000  soporte=100
#  - boquerones           acc= 0.9780  soporte=91
#  - brocoli              acc= 1.0000  soporte=100
#  - calamares            acc= 0.9900  soporte=100
#  - cebollas             acc= 1.0000  soporte=100
#  - cerezas              acc= 0.9762  soporte=84
#  - champinones          acc= 1.0000  soporte=100
#  - chirimoya            acc= 1.0000  soporte=100
#  - chocolate            acc= 0.9900  soporte=100
#  - col                  acc= 1.0000  soporte=100
#  - huevos               acc= 1.0000  soporte=100
#  - judías verdes        acc= 1.0000  soporte=100
#  - langostinos          acc= 1.0000  soporte=85
#  - laurel               acc= 1.0000  soporte=78
#  - leche                acc= 1.0000  soporte=100
#  - lechuga              acc= 1.0000  soporte=92
#  - lentejas             acc= 1.0000  soporte=99
#  - manzana              acc= 1.0000  soporte=100
#  - pan rallado          acc= 1.0000  soporte=100
#  - pasta macarrones     acc= 1.0000  soporte=100
#  - patata               acc= 1.0000  soporte=100
#  - pepino               acc= 1.0000  soporte=100
#  - pera                 acc= 1.0000  soporte=100
#  - perejil              acc= 0.9900  soporte=100
#  - pimentón             acc= 0.9900  soporte=100
#  - pimienta blanca      acc= 0.9792  soporte=96
#  - pimienta negra       acc= 1.0000  soporte=100
#  - pimiento amarillo    acc= 1.0000  soporte=100
#  - pimiento rojo        acc= 0.9900  soporte=100
#  - pimiento verde       acc= 1.0000  soporte=100
#  - pistacho             acc= 1.0000  soporte=97
#  - piñones              acc= 1.0000  soporte=100
#  - platano              acc= 0.9900  soporte=100
#  - puerro               acc= 1.0000  soporte=100
#  - pulpo                acc= 1.0000  soporte=100
#  - queso fresco         acc= 1.0000  soporte=100
#  - queso manchego       acc= 1.0000  soporte=100
#  - quinoa               acc= 1.0000  soporte=100
#  - rabanitos            acc= 1.0000  soporte=100
#  - romero               acc= 0.9900  soporte=100
#  - rucula               acc= 1.0000  soporte=100
#  - sal                  acc= 0.9800  soporte=100
#  - sandia               acc= 1.0000  soporte=99
#  - sardinas             acc= 1.0000  soporte=100
#  - sepia                acc= 1.0000  soporte=100
#  - setas variadas       acc= 1.0000  soporte=100
#  - tomate               acc= 0.9600  soporte=100
#  - tomate cherry        acc= 0.9700  soporte=100
#  - uva                  acc= 1.0000  soporte=100
#  - vinagre balsamico    acc= 1.0000  soporte=100
#  - vino blanco          acc= 0.9897  soporte=97
#  - vino tinto           acc= 1.0000  soporte=100
#  - yogur natural        acc= 1.0000  soporte=98
